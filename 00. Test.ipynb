# %% [markdown]
# # Willkommen

# %% [markdown]
# Anscheinend haben Sie Python erfolgreich installiert.
#
# ### Nun zum Test
#
# Führen Sie folgenden Code unten aus. Gehen Sie dazu wie folgt vor:
#
# * Klikcen Sie auf die nächste Zelle
# * Klicken Sie entweder auf das "Run" Symbol in der Symbolleiste
# * ODER drücken Sie SHIFT + ENTER
#
# Was sehen Sie?

# %%
# %matplotlib inline
from scipy import misc
import matplotlib.pyplot as plt

face = misc.face(gray=True)

fig, ax = plt.subplots(1, 1,figsize=(6, 15))
ax.imshow(face, cmap='gray')
